# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train_first_part = pd.read_excel('train_first_part.xlsx', index_col='id')

# %%
train_second_part = pd.read_json('train_second_part.json').set_index('id')

# %%
weather = pd.read_csv('weather.csv')

# %%
train_first_part
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id3457947          1 2016-02-28 12:09:42 2016-02-28 12:11:57                1
# id2181863          2 2016-06-26 16:22:48 2016-06-26 16:29:43                1
# id1445143          1 2016-05-12 22:43:54 2016-05-12 22:57:24                2
# id1776447          1 2016-03-24 11:43:31 2016-03-24 11:55:03                1
# id0079561          1 2016-05-21 20:51:04 2016-05-21 21:08:59                1
#
# ...

# %%
train_second_part
# Out:
#            vendor_id pickup_datetime dropoff_datetime  passenger_count  \
# id
# id3758523          2     6/2/16 2:30      6/2/16 2:50                6
# id1849264          2    1/6/16 18:12     1/6/16 18:30                5
# id3457947          1   2/28/16 12:09    2/28/16 12:11                1
# id2181863          2   6/26/16 16:22    6/26/16 16:29                1
# id1445143          1   5/12/16 22:43    5/12/16 22:57                2
# ...              ...             ...              ...              ...
# id0002921          1    4/6/16 14:16     4/6/16 14:20                1
# id1329189          2    3/24/16 1:26     3/24/16 1:38                1
# id0408460          1   2/23/16 16:38    2/23/16 16:48                1
# id0147762          1    5/24/16 7:20     5/24/16 7:25                1
# id0859354          2   3/15/16 22:00    3/15/16 22:19                1
#
#            pickup_longitude  pickup_latitude  dropoff_longitude  \
# id
# ...

# %%
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# ..          ...                  ...                  ...
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 0                   38.0          0.00       0.0          0
# 1                   36.0          0.00       0.0          0
# 2                   40.0          0.00       0.0          0
# ...

# %%
train_first_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040022 entries, id2875421 to id0079561
# Data columns (total 10 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   vendor_id           1040022 non-null  int64
#  1   pickup_datetime     1040022 non-null  datetime64[ns]
#  2   dropoff_datetime    1040022 non-null  datetime64[ns]
#  3   passenger_count     1040022 non-null  int64
#  4   pickup_longitude    1040022 non-null  float64
#  5   pickup_latitude     1040022 non-null  float64
#  6   dropoff_longitude   1040022 non-null  float64
#  7   dropoff_latitude    1040022 non-null  float64
#  8   store_and_fwd_flag  1040022 non-null  object
#  9   trip_duration       1040022 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(3), object(1)
# memory usage: 87.3+ MB

# %%
train_first_part['seconds'] = (train_first_part["dropoff_datetime"] - train_first_part["pickup_datetime"]).dt.total_seconds()

# %%
train_second_part['pickup_datetime'] = pd.to_datetime(train_second_part['pickup_datetime'])

# %%
train_second_part['dropoff_datetime'] = pd.to_datetime(train_second_part['dropoff_datetime'])

# %%
train_second_part["seconds"] = (train_second_part["dropoff_datetime"] - train_second_part["pickup_datetime"]).dt.total_seconds()

# %%
train_second_part
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id3758523          2 2016-06-02 02:30:00 2016-06-02 02:50:00                6
# id1849264          2 2016-01-06 18:12:00 2016-01-06 18:30:00                5
# id3457947          1 2016-02-28 12:09:00 2016-02-28 12:11:00                1
# id2181863          2 2016-06-26 16:22:00 2016-06-26 16:29:00                1
# id1445143          1 2016-05-12 22:43:00 2016-05-12 22:57:00                2
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
train_first_part
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id3457947          1 2016-02-28 12:09:42 2016-02-28 12:11:57                1
# id2181863          2 2016-06-26 16:22:48 2016-06-26 16:29:43                1
# id1445143          1 2016-05-12 22:43:54 2016-05-12 22:57:24                2
# id1776447          1 2016-03-24 11:43:31 2016-03-24 11:55:03                1
# id0079561          1 2016-05-21 20:51:04 2016-05-21 21:08:59                1
#
# ...

# %%
train_second_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8587 entries, id3758523 to id0859354
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vendor_id           8587 non-null   int64
#  1   pickup_datetime     8587 non-null   datetime64[ns]
#  2   dropoff_datetime    8587 non-null   datetime64[ns]
#  3   passenger_count     8587 non-null   int64
#  4   pickup_longitude    8587 non-null   float64
#  5   pickup_latitude     8587 non-null   float64
#  6   dropoff_longitude   8587 non-null   float64
#  7   dropoff_latitude    8587 non-null   float64
#  8   store_and_fwd_flag  8587 non-null   object
#  9   trip_duration       8587 non-null   int64
#  10  seconds             8587 non-null   float64
# dtypes: datetime64[ns](2), float64(5), int64(3), object(1)
# memory usage: 805.0+ KB

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 366 non-null    object
#  1   maximum temperature  366 non-null    int64
#  2   minimum temperature  366 non-null    int64
#  3   average temperature  366 non-null    float64
#  4   precipitation        366 non-null    object
#  5   snow fall            366 non-null    object
#  6   snow depth           366 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 20.1+ KB

# %%
weather['date'] = pd.to_datetime(weather['date'])

# %%
weather
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 0   2016-01-01                   42                   34                 38.0
# 1   2016-02-01                   40                   32                 36.0
# 2   2016-03-01                   45                   35                 40.0
# 3   2016-04-01                   36                   14                 25.0
# 4   2016-05-01                   29                   11                 20.0
# ..         ...                  ...                  ...                  ...
# 361 2016-12-27                   60                   40                 50.0
# 362 2016-12-28                   40                   34                 37.0
# 363 2016-12-29                   46                   33                 39.5
# 364 2016-12-30                   40                   33                 36.5
# 365 2016-12-31                   44                   31                 37.5
#
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 366 non-null    datetime64[ns]
#  1   maximum temperature  366 non-null    int64
#  2   minimum temperature  366 non-null    int64
#  3   average temperature  366 non-null    float64
#  4   precipitation        366 non-null    object
#  5   snow fall            366 non-null    object
#  6   snow depth           366 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 20.1+ KB

# %%
weather["precipitation"].value_counts()
# Out:
# 0       116
# 0.00    110
# T        24
# 0.01     12
# 0.04      6
#        ...
# 2.2       1
# 0.30      1
# 1         1
# 0.23      1
# 1.01      1
# Name: precipitation, Length: 63, dtype: int64

# %%
weather['snow fall'].value_counts()
# Out:
# 0       179
# 0.0     162
# T        15
# 0.4       3
# 27.3      1
# 2.8       1
# 1.4       1
# 0.5       1
# 0.1       1
# 0.2       1
# 2.5       1
# Name: snow fall, dtype: int64

# %%
weather['snow depth'].value_counts()
# Out:
# 0     346
# T       7
# 6       4
# 2       2
# 1       2
# 19      1
# 9       1
# 22      1
# 17      1
# 4       1
# Name: snow depth, dtype: int64

# %%
weather = weather.drop(['snow depth'], axis=1)
weather = weather.drop(['snow fall'], axis=1)
weather = weather.drop(['precipitation'], axis=1)

# %%
ax = sns.boxplot(x=weather['minimum temperature'])

# %%
ax = sns.boxplot(x=weather['maximum temperature'])

# %%
ax = sns.boxplot(x=weather['average temperature'])

# %%
weather
# Out:
#           date  maximum temperature  minimum temperature  average temperature
# 0   2016-01-01                   42                   34                 38.0
# 1   2016-02-01                   40                   32                 36.0
# 2   2016-03-01                   45                   35                 40.0
# 3   2016-04-01                   36                   14                 25.0
# 4   2016-05-01                   29                   11                 20.0
# ..         ...                  ...                  ...                  ...
# 361 2016-12-27                   60                   40                 50.0
# 362 2016-12-28                   40                   34                 37.0
# 363 2016-12-29                   46                   33                 39.5
# 364 2016-12-30                   40                   33                 36.5
# 365 2016-12-31                   44                   31                 37.5
#
# [366 rows x 4 columns]

# %%
result = train_first_part.append(train_second_part, ignore_index=False)

# %%
result
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result.index.is_unique
# Out:
# False

# %%
result = result[~result.index.duplicated(keep='first')]

# %%
result.index.is_unique
# Out:
# True

# %%
result
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
cols = list(result.columns.values)  # необязательно, для себя, эстетическаяя красота
cols.insert(4, "seconds")
new_cols = cols[:-1]

# %%
result = result[new_cols]

# %%
result
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result['store_and_fwd_flag'].value_counts(normalize=True)
# Out:
# N    0.99446
# Y    0.00554
# Name: store_and_fwd_flag, dtype: float64

# %%
result = result.drop(['store_and_fwd_flag'], axis=1)

# %%
result
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result['date'] = pd.to_datetime(result['pickup_datetime']).dt.normalize()

# %%
#для совмещения с таблицей weather, создали новый признак date без часов, секунд и минут

# %%
result
# Out:
#            vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# id
# id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...              ...                 ...                 ...              ...
# id0002921          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# id1329189          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# id0408460          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# id0147762          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# id0859354          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result = result.merge(weather, on=['date'], how="left") #запускать только один раз, очень важно

# %%
# указали по какому идёт совмешение(по date)

# %%
result
# Out:
#          vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0                2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# 1                1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# 2                2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# 3                2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# 4                2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...            ...                 ...                 ...              ...
# 1048570          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# 1048571          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# 1048572          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# 1048573          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# 1048574          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result = result.drop(['date'], axis=1)

# %%
result
# Out:
#          vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0                2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# 1                1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# 2                2 2016-01-19 11:35:24 2016-01-19 12:10:48                1
# 3                2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# 4                2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# ...            ...                 ...                 ...              ...
# 1048570          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# 1048571          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# 1048572          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# 1048573          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
# 1048574          2 2016-03-15 22:00:00 2016-03-15 22:19:00                1
#
# ...

# %%
result.passenger_count.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
result.passenger_count.value_counts() #диаграмма в числах
# Out:
# 1    743132
# 2    151078
# 5     56252
# 3     43033
# 6     34700
# 4     20336
# 0        39
# 7         3
# 8         1
# 9         1
# Name: passenger_count, dtype: int64

# %%
# удаляем строки

# %%
result = result.drop(result[result.passenger_count > 6].index)
result = result.drop(result[result.passenger_count == 0].index)

# %%
#ОЧИСТИМ ВЫБРОСЫ В ДАННЫХ

# %%
ax = sns.boxplot(x=result["passenger_count"])

# %%
ax = sns.boxplot(x=result["trip_duration"])

# %%
#по какому значению нужно срезать выбросы, до какого значения лежит большая часть данных

# %%
result.trip_duration.quantile(0.92)
# Out:
# 1780.0

# %%
result = result.drop(result[result.trip_duration > 1080].index) # выбросы по целевой переменной

# %%
ax = sns.boxplot(x=result["trip_duration"])

# %%
result
# Out:
#          vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0                2 2016-03-14 17:24:55 2016-03-14 17:32:30                1
# 1                1 2016-06-12 00:43:35 2016-06-12 00:54:38                1
# 3                2 2016-04-06 19:32:31 2016-04-06 19:39:40                1
# 4                2 2016-03-26 13:30:55 2016-03-26 13:38:10                1
# 5                2 2016-01-30 22:01:40 2016-01-30 22:09:03                6
# ...            ...                 ...                 ...              ...
# 1048568          1 2016-05-04 11:24:00 2016-05-04 11:34:00                1
# 1048570          1 2016-04-06 14:16:00 2016-04-06 14:20:00                1
# 1048571          2 2016-03-24 01:26:00 2016-03-24 01:38:00                1
# 1048572          1 2016-02-23 16:38:00 2016-02-23 16:48:00                1
# 1048573          1 2016-05-24 07:20:00 2016-05-24 07:25:00                1
#
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 788804 entries, 0 to 1048573
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   vendor_id            788804 non-null  int64
#  1   pickup_datetime      788804 non-null  datetime64[ns]
#  2   dropoff_datetime     788804 non-null  datetime64[ns]
#  3   passenger_count      788804 non-null  int64
#  4   seconds              788804 non-null  float64
#  5   pickup_longitude     788804 non-null  float64
#  6   pickup_latitude      788804 non-null  float64
#  7   dropoff_longitude    788804 non-null  float64
#  8   dropoff_latitude     788804 non-null  float64
#  9   trip_duration        788804 non-null  int64
#  10  maximum temperature  788804 non-null  int64
#  11  minimum temperature  788804 non-null  int64
#  12  average temperature  788804 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(5)
# memory usage: 84.3 MB

# %%
#выбросы по координатам посадки и высадки

# %%
result = result.drop(result[result.pickup_longitude < -74.02].index)

# %%
result = result.drop(result[result.pickup_longitude > -73.94].index)

# %%
ax = sns.boxplot(x=result["pickup_longitude"])

# %%
result = result.drop(result[result.pickup_latitude < 40.7].index)

# %%
result = result.drop(result[result.pickup_latitude > 40.8].index)

# %%
ax = sns.boxplot(x=result["pickup_latitude"])

# %%
result = result.drop(result[result.dropoff_longitude > -73.935].index)

# %%
result = result.drop(result[result.dropoff_longitude < -74.025].index)

# %%
ax = sns.boxplot(x=result["dropoff_longitude"])

# %%
result.index.name = 'id'

# %%
result.to_csv("data.csv")

# %%
# ВТОРОЙ МОДУЛЬ

# %%
result = pd.read_csv('data.csv', index_col='id')

# %%
result
# Out:
#          vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# id
# 0                2  2016-03-14 17:24:55  2016-03-14 17:32:30                1
# 1                1  2016-06-12 00:43:35  2016-06-12 00:54:38                1
# 3                2  2016-04-06 19:32:31  2016-04-06 19:39:40                1
# 4                2  2016-03-26 13:30:55  2016-03-26 13:38:10                1
# 5                2  2016-01-30 22:01:40  2016-01-30 22:09:03                6
# ...            ...                  ...                  ...              ...
# 1048568          1  2016-05-04 11:24:00  2016-05-04 11:34:00                1
# 1048570          1  2016-04-06 14:16:00  2016-04-06 14:20:00                1
# 1048571          2  2016-03-24 01:26:00  2016-03-24 01:38:00                1
# 1048572          1  2016-02-23 16:38:00  2016-02-23 16:48:00                1
# 1048573          1  2016-05-24 07:20:00  2016-05-24 07:25:00                1
#
# ...

# %%
result['pickup_datetime'] = pd.to_datetime(result['pickup_datetime']).dt.normalize()
result['dropoff_datetime'] = pd.to_datetime(result['dropoff_datetime']).dt.normalize()

# %%
result["pickup_year"] = result['pickup_datetime'].dt.year
result['pickup_monthr'] = result['pickup_datetime'].dt.month
result['pickup_day'] = result['pickup_datetime'].dt.day

# %%
result = result.drop(['pickup_datetime'], axis=1)
result = result.drop(['dropoff_datetime'], axis=1)

# %%
result
# Out:
#          vendor_id  passenger_count  seconds  pickup_longitude  \
# id
# 0                2                1    455.0        -73.982155
# 1                1                1    663.0        -73.980415
# 3                2                1    429.0        -74.010040
# 4                2                1    435.0        -73.973053
# 5                2                6    443.0        -73.982857
# ...            ...              ...      ...               ...
# 1048568          1                1    600.0        -73.976509
# 1048570          1                1    240.0        -73.973015
# 1048571          2                1    720.0        -73.985550
# 1048572          1                1    600.0        -73.972038
# 1048573          1                1    300.0        -73.993332
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude  trip_duration  \
# id
# 0              40.767937         -73.964630         40.765602            455
# ...
